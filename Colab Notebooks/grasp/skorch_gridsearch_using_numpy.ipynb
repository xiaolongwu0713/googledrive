# %%
! pip install mne==0.19.2
! pip install torch
! pip install skorch
# Out:
# Requirement already satisfied: mne==0.19.2 in /usr/local/lib/python3.7/dist-packages (0.19.2)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from mne==0.19.2) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from mne==0.19.2) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied: skorch in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from skorch) (0.22.2.post1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from skorch) (0.8.9)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from skorch) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from skorch) (1.19.5)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.7/dist-packages (from skorch) (4.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->skorch) (1.0.1)

# %%
# %cd /content/drive/MyDrive/
# raw_data is imported from global config
root_dir='/content/drive/MyDrive/'  # ChangeThis
result_dir=root_dir+'grasp/TSception/result_subject2/'
# Out:
# /content/drive/MyDrive

# %%
import os, re
location=os.getcwd()
print(location)
# Out:
# /content/drive/MyDrive

# %%
print(re.compile('/content/drive').match(location))
# Out:
# <re.Match object; span=(0, 14), match='/content/drive'>

# %%
import sys, importlib
#importlib.reload(sys.modules['grasp.config'])
from grasp.config import *
# orveride the data_dir in config file
#data_dir='/content/drive/MyDrive/data/' # googleDrive

# %%
data_dir
# Out:
# '/content/drive/MyDrive/data/'

# %%
import torch
from skorch.helper import predefined_split
from torch import nn
import torch.nn.functional as F
from skorch import NeuralNetRegressor
from skorch.callbacks import Callback
import numpy as np
import matplotlib.pyplot as plt

from grasp.TSception.Models import TSception2
from grasp.utils import freq_input,SEEGDataset,set_random_seeds,cuda_or_cup,windTo3D_x, windTo3D_y
from grasp.config import root_dir, tmp_dir
from grasp.myskorch import plotPrediction, MyRegressor

# %%
# reload function
import sys, importlib
importlib.reload(sys.modules['grasp.TSception.Models'])
importlib.reload(sys.modules['grasp.utils'])
importlib.reload(sys.modules['grasp.config'])
from grasp.TSception.Models import TSception,TSception2
from grasp.utils import freq_input,SEEGDataset

# %%
# import from another folder
import sys
sys.path.insert(1, '/content/drive/MyDrive/examples')
from IMV_LSTM.networks import IMVTensorLSTM

# %%
import inspect as i
import sys
#sys.stdout.write(i.getsource(rawData2));

# %%
device=cuda_or_cup()
seed = 123456789  # random seed to make results reproducible
# Set random seed to be able to reproduce results
set_random_seeds(seed=seed)
# Out:
# GPU computing:   False

# %%
# %%capture
# suppress the output
sid=6
sampling_rate=1000
traindata, valdata, testdata = freq_input(sid,split=True,move2=True)  # (chns, 15000/15001, 118) (channels, time, trials)
##traindata, valdata, testdata = rawData2('raw','all',move2=True)
traindata = traindata.transpose(2, 0, 1)  # (118, 20, 15000) (trials,channels,  time)
valdata = valdata.transpose(2, 0, 1) # (8, 20, 15000)
testdata = testdata.transpose(2, 0, 1)  # (8, 20, 15000)

trainx, trainy = traindata[:, :-2, :], traindata[:, -2, :] #-2 is real force, -1 is target
valx, valy = valdata[:, :-2, :], valdata[:, -2, :]
testx, testy = testdata[:, :-2, :], testdata[:, -2, :]
# trainx.shape(trials, channels,times)
# trainy.shape(trials, times)

# %%
# put train and valdate togather, CV will do the split automatically
train_and_valx=np.concatenate((trainx,valx),axis=0)
train_and_valy=np.concatenate((trainy,valy),axis=0)
del trainx, valx, trainy, valy,testx,testy, traindata, valdata,testdata

# %%
# prevent crash on memory usage
train_and_valx=train_and_valx[:60,:,:]
train_and_valy=train_and_valy[:60,:]

# %%
#samples=trainx.shape[0]
chnNum=train_and_valx.shape[1]
step=50 #ms
T=1000 #ms
totalLen=train_and_valx.shape[2] #ms
batch_size=int((totalLen-T)/step) # 280

# %%
train_and_val_wind_x=[]
for trial in range(train_and_valx.shape[0]):
    print(str(trial)+' out of '+str(train_and_valx.shape[0]))
    train_and_val_wind_x.append([])
    train_and_val_wind_x[trial]=windTo3D_x(train_and_valx[trial],T,step)
del train_and_valx
train_and_val_final_x=np.stack( train_and_val_wind_x) # (10, 280, 1, 90, 1000)
del train_and_val_wind_x

# %%
train_and_val_wind_y=[]
for trial in range(train_and_valy.shape[0]):
    train_and_val_wind_y.append([])
    train_and_val_wind_y[trial]=windTo3D_y(train_and_valy[trial],T,step)
del train_and_valy
train_and_val_final_y=np.stack( train_and_val_wind_y) # (10, 280, 1)
del train_and_val_wind_y

# %%
learning_rate=0.001
num_T = 3 # (6 conv2d layers) * ( 3 kernel each layer)
num_S = 3
num_ST=3
dropout=0.5
#Lambda = 1e-6
Lambda = 0
# do not initialize here. Do it in net definition.
#model=TSception2(T, step, sampling_rate,chnNum, num_T, num_S,batch_size,dropout).float()

#if(enable_cuda):
#	model.cuda()

# %%
from skorch.callbacks import Checkpoint, TrainEndCheckpoint, EarlyStopping
cp = Checkpoint(dirname=result_dir) # Will automatically save the model when there is an improvement during validation.
train_end_cp = TrainEndCheckpoint(dirname=result_dir) # save model and the end of the training

early_stopping_callbacks = EarlyStopping(monitor='valid_loss', lower_is_better=True, patience=5)

# %%
net = MyRegressor(
    module=TSception2,
    module__wind_size=T,
    module__step=step,
    module__sampling_rate=sampling_rate,
    module__chnNum=chnNum,
    module__num_T=num_ST,
    module__num_S=num_ST,
    module__batch_size=batch_size,
    module__dropout=dropout,
    lambda1=Lambda,
    iterator_train__shuffle=True,
    #train_split=predefined_split(val_ds), #disable this when do grid search
    train_split=None, # grid search
    verbose=0, # grid search
    max_epochs=100,
    lr=learning_rate,
    batch_size=1,
    optimizer=torch.optim.Adam,
    criterion = nn.MSELoss,
    callbacks=[('plotPrediction', plotPrediction(result_dir)),cp,train_end_cp,early_stopping_callbacks], # early_stopping_callbacks
    device = device
)

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'lr': [0.001, 0.003],
    'module__num_S':[2,3],
    'module__num_T':[2,3,4,5,6],
    'module__dropout':[0.1,0.3,0.5,0.7],
    'optimizer': [torch.optim.Adam, torch.optim.Adagrad ,torch.optim.SGD],
    'optimizer__weight_decay':[0, 1e-04, 1e-03],
    #'max_epochs': [100,200, 300],
    #'module__num_units': [10, 20],
}
'''
params = {
    'lr': [0.001, 0.003,0.005,0.01],
    'module__num_S':[2,3,4,5,6],
    'module__num_T':[2,3,4,5,6],
    'module__dropout':[0.1,0.3,0.5,0.7],
    'optimizer': [torch.optim.Adam, torch.optim.Adagrad ,torch.optim.SGD],
    'optimizer__weight_decay':[0, 1e-04, 1e-03],
    #'max_epochs': [100,200, 300],
    #'module__num_units': [10, 20],
}
'''
# note
# 1, gridsearch will do the training and validate set split itself. so set train_split=False according to https://nbviewer.jupyter.org/github/skorch-dev/skorch/blob/master/notebooks/Basic_Usage.ipynb#Performing-a-grid-search
# 2, how to search on different optimizor?
# Out:
# "\nparams = {\n    'lr': [0.001, 0.003,0.005,0.01],\n    'module__num_S':[2,3,4,5,6],\n    'module__num_T':[2,3,4,5,6],\n    'module__dropout':[0.1,0.3,0.5,0.7],\n    'optimizer': [torch.optim.Adam, torch.optim.Adagrad ,torch.optim.SGD],\n    'optimizer__weight_decay':[0, 1e-04, 1e-03],\n    #'max_epochs': [100,200, 300],\n    #'module__num_units': [10, 20],\n}\n"

# %%
#net.fit(train_ds,y=None)
gs = GridSearchCV(net, params, refit=False, cv=5, scoring='neg_mean_squared_error', verbose=2) # score: higher is better
gs.fit(train_and_val_final_x,train_and_val_final_y)
# Out:
# Fitting 5 folds for each of 720 candidates, totalling 3600 fits
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Epoch 1.
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# RuntimeError: expected scalar type Double but found Float
#
#   FitFailedWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   14.8s remaining:    0.0s
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=  14.6s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.9s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=3, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.7s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   4.4s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.9s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   4.3s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.9s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.9s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=4, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   3.8s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=2, module__num_T=5, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# ...
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   4.2s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   4.2s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.0001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.1, module__num_S=3, module__num_T=6, optimizer=<class 'torch.optim.sgd.SGD'>, optimizer__weight_decay=0.001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   4.2s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   4.3s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   4.2s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.0001, total=   4.2s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   4.2s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   4.2s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adam.Adam'>, optimizer__weight_decay=0.001, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   4.2s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   4.1s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0, total=   4.2s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   4.2s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# Epoch 1.
# [CV]  lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001, total=   4.2s
# [CV] lr=0.001, module__dropout=0.3, module__num_S=2, module__num_T=2, optimizer=<class 'torch.optim.adagrad.Adagrad'>, optimizer__weight_decay=0.0001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-8da98ec88b61> in <module>()
#       1 #net.fit(train_ds,y=None)
#       2 gs = GridSearchCV(net, params, refit=False, cv=5, scoring='neg_mean_squared_error', verbose=2) # score: higher is better
# ----> 3 gs.fit(train_and_val_final_x,train_and_val_final_y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     506     start_time = time.time()
#     507
# --> 508     X_train, y_train = _safe_split(estimator, X, y, train)
#     509     X_test, y_test = _safe_split(estimator, X, y, test, train)
#     510
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/metaestimators.py in _safe_split(estimator, X, y, indices, train_indices)
#     199             X_subset = X[np.ix_(indices, train_indices)]
#     200     else:
# --> 201         X_subset = _safe_indexing(X, indices)
#     202
#     203     if y is not None:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/__init__.py in _safe_indexing(X, indices, axis)
#     411         return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     412     elif hasattr(X, "shape"):
# --> 413         return _array_indexing(X, indices, indices_dtype, axis=axis)
#     414     else:
#     415         return _list_indexing(X, indices, indices_dtype)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/__init__.py in _array_indexing(array, key, key_dtype, axis)
#     197     if isinstance(key, tuple):
#     198         key = list(key)
# --> 199     return array[key] if axis == 0 else array[:, key]
#     200
#     201
#
# KeyboardInterrupt:

# %%
import sklearn
#sorted(sklearn.metrics.SCORERS.keys())

# %%
print(gs.best_score_, gs.best_params_)
